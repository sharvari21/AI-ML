# %% [markdown]
# # Question 1:
# __● Using the given MT cars dataset you need to find outlier with z score.__

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import os
from scipy import stats

# %%
pd.__version__
# Out:
# '1.0.5'

# %%
os.chdir('D:\\aiml')
os.getcwd()
# Out:
# 'D:\\aiml'

# %%
car_data = pd.read_csv('mtcars.csv')
car_data.head(10)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9           Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4

# %%
car_data['model']=pd.to_numeric(car_data['model'], errors='coerce')
car_data
df = car_data.apply(stats.zscore)
df
# Out:
#     model       mpg       cyl      disp        hp      drat        wt  \
# 0     NaN  0.153299 -0.106668 -0.579750 -0.543655  0.576594 -0.620167
# 1     NaN  0.153299 -0.106668 -0.579750 -0.543655  0.576594 -0.355382
# 2     NaN  0.456737 -1.244457 -1.006026 -0.795570  0.481584 -0.931678
# 3     NaN  0.220730 -0.106668  0.223615 -0.543655 -0.981576 -0.002336
# 4     NaN -0.234427  1.031121  1.059772  0.419550 -0.848562  0.231297
# 5     NaN -0.335572 -0.106668 -0.046906 -0.617748 -1.589643  0.252064
# 6     NaN -0.976163  1.031121  1.059772  1.456847 -0.734549  0.366285
# 7     NaN  0.726459 -1.244457 -0.688779 -1.254944  0.177551 -0.028296
# 8     NaN  0.456737 -1.244457 -0.737144 -0.765933  0.614599 -0.069830
# 9     NaN -0.150138 -0.106668 -0.517448 -0.351014  0.614599  0.231297
# 10    NaN -0.386145 -0.106668 -0.517448 -0.351014  0.614599  0.231297
# 11    NaN -0.622152  1.031121  0.369533  0.493642 -1.000578  0.885470
# ...

# %%
val = df[df > 3]
val
# Out:
#     model  mpg  cyl  disp  hp  drat  wt  qsec  vs  am  gear      carb
# 0     NaN  NaN  NaN   NaN NaN   NaN NaN   NaN NaN NaN   NaN       NaN
# 1     NaN  NaN  NaN   NaN NaN   NaN NaN   NaN NaN NaN   NaN       NaN
# 2     NaN  NaN  NaN   NaN NaN   NaN NaN   NaN NaN NaN   NaN       NaN
# 3     NaN  NaN  NaN   NaN NaN   NaN NaN   NaN NaN NaN   NaN       NaN
# 4     NaN  NaN  NaN   NaN NaN   NaN NaN   NaN NaN NaN   NaN       NaN
# 5     NaN  NaN  NaN   NaN NaN   NaN NaN   NaN NaN NaN   NaN       NaN
# 6     NaN  NaN  NaN   NaN NaN   NaN NaN   NaN NaN NaN   NaN       NaN
# 7     NaN  NaN  NaN   NaN NaN   NaN NaN   NaN NaN NaN   NaN       NaN
# 8     NaN  NaN  NaN   NaN NaN   NaN NaN   NaN NaN NaN   NaN       NaN
# 9     NaN  NaN  NaN   NaN NaN   NaN NaN   NaN NaN NaN   NaN       NaN
# 10    NaN  NaN  NaN   NaN NaN   NaN NaN   NaN NaN NaN   NaN       NaN
# 11    NaN  NaN  NaN   NaN NaN   NaN NaN   NaN NaN NaN   NaN       NaN
# ...

# %%
pl = car_data.boxplot('carb')
pl.annotate('outlierpoint', (1,7.5))
# Out:
# Text(1, 7.5, 'outlierpoint')

# %% [markdown]
# # Question 2:
# __● Using the Boston data set from sklearn, find out the Outlier and treat them.__

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston

# %%
df = load_boston()
print(df.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
columns = df.feature_names
print(columns)
x = df.data
y = df.target
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
data = pd.DataFrame(x, columns=columns)
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
# df1 = np.abs(stats.zscore(data))
# type(df1)
# Out:
# numpy.ndarray

# %%
df1 = np.abs(data.apply(stats.zscore))
df1
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0    0.419782  0.284830  1.287909  0.272599  0.144217  0.413672  0.120013
# 1    0.417339  0.487722  0.593381  0.272599  0.740262  0.194274  0.367166
# 2    0.417342  0.487722  0.593381  0.272599  0.740262  1.282714  0.265812
# 3    0.416750  0.487722  1.306878  0.272599  0.835284  1.016303  0.809889
# 4    0.412482  0.487722  1.306878  0.272599  0.835284  1.228577  0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501  0.413229  0.487722  0.115738  0.272599  0.158124  0.439316  0.018673
# 502  0.415249  0.487722  0.115738  0.272599  0.158124  0.234548  0.288933
# 503  0.413447  0.487722  0.115738  0.272599  0.158124  0.984960  0.797449
# 504  0.407764  0.487722  0.115738  0.272599  0.158124  0.725672  0.736996
# 505  0.415000  0.487722  0.115738  0.272599  0.158124  0.362767  0.434732
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# ...

# %%
out_val = df1[df1 > 3]
out_val
# Out:
#      CRIM  ZN  INDUS  CHAS  NOX  RM  AGE  DIS  RAD  TAX  PTRATIO   B  LSTAT
# 0     NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN    NaN
# 1     NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN    NaN
# 2     NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN    NaN
# 3     NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN    NaN
# 4     NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN    NaN
# ..    ...  ..    ...   ...  ...  ..  ...  ...  ...  ...      ...  ..    ...
# 501   NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN    NaN
# 502   NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN    NaN
# 503   NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN    NaN
# 504   NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN    NaN
# 505   NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN NaN    NaN
#
# [506 rows x 13 columns]

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df1['INDUS'], df1['TAX'])
ax.set_xlabel('Proportion of non-retail business acres per town')
ax.set_ylabel('Full-value property-tax rate per $10,000')
plt.show()

# %% [markdown]
# ## Finding IQR

# %%
boston_df_o = data

boston_df_o = boston_df_o[(z < 3).all(axis=1)]

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# %%
boston_df_2 = boston_df_o[~((boston_df_o < lower) | (boston_df_o > upper)).any(axis = 1)]

# %%
df11 = boston_df_2.apply(stats.zscore)
# Out:
# C:\Users\sharv\anaconda3\lib\site-packages\scipy\stats\stats.py:2500: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd

# %%
boston_df_o[~((boston_df_o < lower) & (boston_df_o > upper)).any(axis = 1)]
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...
